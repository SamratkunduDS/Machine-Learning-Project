# %% [markdown]
# # LINEAR REGRESSION PROJECT

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Raw_Housing_Prices.csv')

# %%
df
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        21613 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   4
# No of Bedrooms                               0
# No of Bathrooms                              4
# Flat Area (in Sqft)                          9
# Lot Area (in Sqft)                           9
# No of Floors                                 0
# Waterfront View                              0
# No of Times Visited                          0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    3
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      1
# Latitude                                     1
# Longitude                                    1
# Living Area after Renovation (in Sqft)       1
# ...

# %%
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                None  ...             7
# ...

# %%
df.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %%
df['Sale Price'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Sale Price'].isnull().sum()
# Out:
# 4

# %%
df['Sale Price'].dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        21613 non-null  object
# ...

# %%
df['Sale Price'].describe()
# Out:
# count    2.160900e+04
# mean     5.401984e+05
# std      3.673890e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: Sale Price, dtype: float64

# %% [markdown]
# ### Treating outliers by the method of imputing

# %%
q1 = df['Sale Price'].quantile(0.25)
q3= df['Sale Price'].quantile(0.75)

# %%
q1
# Out:
# 321950.0

# %%
q3
# Out:
# 645000.0

# %%
iqr = q3 - q1
iqr
# Out:
# 323050.0

# %%
upper_limit = q3 + 1.5*iqr
lower_limit = q1 - 1.5*iqr

# %%
def limit_imputer(value):
    if value > upper_limit:
        return upper_limit
    if value < lower_limit:
        return lower_limit
    else:
        return value

# %%
df['Sale Price'] = df['Sale Price'].apply(limit_imputer)

# %%
df['Sale Price'].describe()
# Out:
# count    2.160900e+04
# mean     5.116186e+05
# std      2.500620e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      1.129575e+06
# Name: Sale Price, dtype: float64

# %%
df['Sale Price'].isnull().sum()
# Out:
# 4

# %%
df['Sale Price'].dropna(inplace = True)

# %%
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                None  ...             7
# ...

# %%
number_col = ['No of Bathrooms', 'Flat Area (in Sqft)','Lot Area (in Sqft)','Area of the House from Basement (in Sqft)','Latitude','Longitude','Living Area after Renovation (in Sqft)']

# %%
number_col
# Out:
# ['No of Bathrooms',
#  'Flat Area (in Sqft)',
#  'Lot Area (in Sqft)',
#  'Area of the House from Basement (in Sqft)',
#  'Latitude',
#  'Longitude',
#  'Living Area after Renovation (in Sqft)']

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values = np.nan, strategy = 'median')
df[number_col] = imputer.fit_transform(df[number_col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21613 non-null  float64
#  5   Flat Area (in Sqft)                        21613 non-null  float64
#  6   Lot Area (in Sqft)                         21613 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        21613 non-null  object
# ...

# %%
imputer = SimpleImputer(missing_values = np.nan, strategy = 'most_frequent')
df['Zipcode'] = imputer.fit_transform(zp)

# %%
df['Zipcode'].shape
# Out:
# (21613,)

# %%
zp = df["Zipcode"].values.reshape(-1,1)

# %%
zp.shape
# Out:
# (21613, 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21613 non-null  float64
#  5   Flat Area (in Sqft)                        21613 non-null  float64
#  6   Lot Area (in Sqft)                         21613 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        21613 non-null  object
# ...

# %%
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                None  ...             7
# ...

# %%
df['No of Times Visited'].unique()
# Out:
# array(['None', 'Thrice', 'Four', 'Twice', 'Once'], dtype=object)

# %%
mapping = {'None' : '0', 'Once':'1','Twice':'2','Thrice':'3','Four':'4'}

# %%
df['No of Times Visited'] = df['No of Times Visited'].map(mapping)

# %%
df['No of Times Visited'].unique()
# Out:
# array(['0', '3', '4', '2', '1'], dtype=object)

# %%
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                   0  ...             7
# ...

# %% [markdown]
# ## Adding Column

# %%
df['Renovated'] = np.where(df['Renovated Year'] == 0, 'No','Yes')
df['Renovated'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ...  \
# 0              No                   0  ...
# 1              No                   0  ...
# ...

# %%
df['Purchase Year'] = pd.DatetimeIndex(df['Date House was Sold']).year

# %%
df['Years since Renovation'] = np.where(df['Renovated'] == 'Yes',abs(df['Purchase Year']) - df['Renovated Year'],0)

# %%
df.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Age of House (in Years)  \
# 0              No                   0  ...                      63
# ...

# %%
df.drop(columns = ['Purchase Year','Date House was Sold', 'Renovated Year'], inplace =True)
df.head()
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront View  \
# 0               1180.0              5650.0           1.0              No
# 1               2570.0              7242.0           2.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
#
#   No of Times Visited Condition of the House  ...  \
# 0                   0                   Fair  ...
# 1                   0                   Fair  ...
# ...

# %%
#since we dont need the column ID so we are dropping that column too.
df.drop(columns = ['ID'],inplace = True)
df.head()
# Out:
#    Sale Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors Waterfront View No of Times Visited  \
# 0              5650.0           1.0              No                   0
# 1              7242.0           2.0              No                   0
# 2             10000.0           1.0              No                   0
# 3              5000.0           1.0              No                   0
# 4              8080.0           1.0              No                   0
#
#   Condition of the House  Overall Grade  \
# 0                   Fair              7
# ...

# %%
df['Condition of the House'].unique()
# Out:
# array(['Fair', 'Excellent', 'Good', 'Bad', 'Okay'], dtype=object)

# %%
df.groupby('Condition of the House')['Sale Price'].mean().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Condition of the House'>

# %%
mapping = {'Bad' : '1', 'Okay' : '2', 'Good' : '3' , 'Fair' : '4', 'Excellent' : '5'}
df['Condition of the House'] = df['Condition of the House'].map(mapping)

# %%
df.head()
# Out:
#    Sale Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors Waterfront View No of Times Visited  \
# 0              5650.0           1.0              No                   0
# 1              7242.0           2.0              No                   0
# 2             10000.0           1.0              No                   0
# 3              5000.0           1.0              No                   0
# 4              8080.0           1.0              No                   0
#
#   Condition of the House  Overall Grade  \
# 0                      4              7
# ...

# %%
mpng = {'Yes' : '1', 'No' : '0'}
df['Waterfront View'] = df['Waterfront View'].map(mpng)

# %%
df.head()
# Out:
#    Sale Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors Waterfront View No of Times Visited  \
# 0              5650.0           1.0               0                   0
# 1              7242.0           2.0               0                   0
# 2             10000.0           1.0               0                   0
# 3              5000.0           1.0               0                   0
# 4              8080.0           1.0               0                   0
#
#   Condition of the House  Overall Grade  \
# 0                      4              7
# ...

# %%
num_col = ['No of Bedrooms', 'No of Bathrooms', 'Lot Area (in Sqft)',
       'No of Floors',
       'Area of the House from Basement (in Sqft)', 'Basement Area (in Sqft)',
       'Age of House (in Years)', 'Latitude', 'Longitude',
       'Living Area after Renovation (in Sqft)',
       'Lot Area after Renovation (in Sqft)']

# %%
def bar_graph(data, var):
    plt.figure(figsize = (len(var)*5,5), dpi = 100)
    for j,i in enumerate(var):
        plt.subplot(1,len(var),j+1)
        plt.hist(data[i])
        plt.title(i)

# %%
bar_graph(df.drop(columns = ['Sale Price']),num_col)

# %% [markdown]
# #### as most the graph is rightly skewed we need to fix this and transform it into normal distribution

# %%
def log_transform(sample_data):
    return np.log(abs(sample_data+500))

# %%
#Lets split the data into X and y
df.dropna(inplace = True)
X = df.drop(columns = ['Sale Price'])
y = df['Sale Price']

# %%
X
# Out:
#        No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0                   3             1.00               1180.0
# 1                   3             2.25               2570.0
# 2                   2             1.00                770.0
# 3                   4             3.00               1960.0
# 4                   3             2.00               1680.0
# ...               ...              ...                  ...
# 21608               3             2.50               1530.0
# 21609               4             2.50               2310.0
# 21610               2             0.75               1020.0
# 21611               3             2.50               1600.0
# 21612               2             0.75               1020.0
#
#        Lot Area (in Sqft)  No of Floors Waterfront View No of Times Visited  \
# 0                  5650.0           1.0               0                   0
# 1                  7242.0           2.0               0                   0
# ...

# %%
for i in num_col:
    X[i] = X[i].map(log_transform)

# %%
X.head()
# Out:
#    No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  \
# 0        6.220590         6.216606               1180.0            8.724207
# 1        6.220590         6.219098               2570.0            8.954415
# 2        6.218600         6.216606                770.0            9.259131
# 3        6.222576         6.220590               1960.0            8.612503
# 4        6.220590         6.218600               1680.0            9.057189
#
#    No of Floors Waterfront View No of Times Visited Condition of the House  \
# 0      6.216606               0                   0                      4
# 1      6.218600               0                   0                      4
# 2      6.216606               0                   0                      4
# 3      6.216606               0                   0                      5
# 4      6.216606               0                   0                      4
#
# ...

# %%
bar_graph(X,num_col)

# %%
## Now scaling the datasets
X.dropna(inplace= True)

# %%
X.drop(columns=['Renovated'], inplace =True)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df = scaler.fit_transform(X)

# %%
df = pd.DataFrame(data = df,columns = X.columns)

# %%
df
# Out:
#        No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0           -0.398647        -1.448931            -0.979905
# 1           -0.398647         0.176496             0.533718
# 2           -1.477788        -1.448931            -1.426369
# 3            0.678352         1.149811            -0.130534
# 4           -0.398647        -0.148266            -0.435436
# ...               ...              ...                  ...
# 21604       -0.398647         0.501095            -0.598777
# 21605        0.678352         0.501095             0.250594
# 21606       -1.477788        -1.774502            -1.154135
# 21607       -0.398647         0.501095            -0.522551
# 21608       -1.477788        -1.774502            -1.154135
#
#        Lot Area (in Sqft)  No of Floors  Waterfront View  No of Times Visited  \
# 0               -0.412101     -0.915604        -0.087181             -0.30579
# 1               -0.139474      0.937193        -0.087181             -0.30579
# ...

# %% [markdown]
# ### Applying Train and Test Split

# %%
X = df

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,y, test_size = 0.2, random_state = 100)

x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((17287, 18), (4322, 18), (17287,), (4322,))

# %%
## Predicting values using Linear Regression
from sklearn.linear_model import LinearRegression
linear = LinearRegression()

# %%
y_train.isnull().sum()
# Out:
# 0

# %%
linear.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = linear.predict(x_test)

# %%
y_pred
# Out:
# array([289040.34092541, 345332.95790457, 509903.41850552, ...,
#        402395.55623781, 412226.96601856, 323375.63692967])

# %%
y_test
# Out:
# 17277     220000.0
# 14195     473600.0
# 10364     536500.0
# 5587      450000.0
# 20916     525000.0
#            ...
# 12241     197400.0
# 11018    1129575.0
# 12898     443950.0
# 2786      669000.0
# 13564     299000.0
# Name: Sale Price, Length: 4322, dtype: float64

# %%
from sklearn.metrics import *
r2_score(y_test,y_pred)
# Out:
# 0.7444611165872724
